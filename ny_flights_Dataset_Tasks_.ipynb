# %%
#question 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/diabetes_model.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
df2 = pd.read_csv('/content/ny-flights.csv')
df2.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %%
combined_df = pd.concat([df1,df2], ignore_index=True)
combined_df
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5.0     77.0           82.0           41.0     42.0  35.8
# 1              9.0    122.0           56.0            0.0      0.0  33.3
# 2              0.0    113.0           76.0            0.0      0.0  33.3
# 3              1.0    139.0           62.0           41.0    480.0  40.7
# 4             10.0    161.0           68.0           23.0    132.0  25.5
# ...            ...      ...            ...            ...      ...   ...
# 21426          NaN      NaN            NaN            NaN      NaN   NaN
# 21427          NaN      NaN            NaN            NaN      NaN   NaN
# 21428          NaN      NaN            NaN            NaN      NaN   NaN
# 21429          NaN      NaN            NaN            NaN      NaN   NaN
# 21430          NaN      NaN            NaN            NaN      NaN   NaN
#
#        DiabetesPedigreeFunction   Age  Outcome              fl_date  ...  \
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21431 entries, 0 to 21430
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    float64
#  1   Glucose                   614 non-null    float64
#  2   BloodPressure             614 non-null    float64
#  3   SkinThickness             614 non-null    float64
#  4   Insulin                   614 non-null    float64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    float64
#  8   Outcome                   614 non-null    float64
#  9   fl_date                   20817 non-null  object
#  10  unique_carrier            20817 non-null  object
#  11  airline_id                20817 non-null  float64
#  12  tail_num                  20512 non-null  object
# ...

# %%
combined_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.845277  121.500000      69.599349      20.400651   79.035831
# std       3.403362   32.275918      18.924485      16.113962  117.108037
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      22.500000   24.000000
# 75%       6.000000  141.000000      80.000000      33.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome  \
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.210423                  0.476373   33.289902    0.350163
# std      7.965291                  0.343502   11.837425    0.477410
# ...

# %%
combined_df.isnull().sum()
# Out:
# Pregnancies                 20817
# Glucose                     20817
# BloodPressure               20817
# SkinThickness               20817
# Insulin                     20817
# BMI                         20817
# DiabetesPedigreeFunction    20817
# Age                         20817
# Outcome                     20817
# fl_date                       614
# unique_carrier                614
# airline_id                    614
# tail_num                      919
# fl_num                        614
# origin                        614
# dest                          614
# dep_time                     2969
# dep_delay                    2969
# arr_time                     3019
# arr_delay                    3048
# cancelled                     614
# arr                          3019
# dep                          2969
# dtype: int64

# %%
combined_df.duplicated().sum()
# Out:
# 0

# %%
combined_df["Pregnancies"].mean()
# Out:
# 3.8452768729641695

# %%
combined_df["Pregnancies"].median()
# Out:
# 3.0

# %%
combined_df["Pregnancies"].mode()
# Out:
# 0    1.0
# Name: Pregnancies, dtype: float64

# %%
combined_df["Pregnancies"].value_counts()
# Out:
# Pregnancies
# 1.0     108
# 0.0      93
# 2.0      79
# 3.0      59
# 4.0      52
# 5.0      48
# 7.0      37
# 6.0      37
# 8.0      32
# 9.0      24
# 10.0     17
# 11.0      9
# 13.0      8
# 12.0      7
# 14.0      2
# 17.0      1
# 15.0      1
# Name: count, dtype: int64

# %%
combined_df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0.0         3.343358  110.167920      68.809524      19.380952   67.528822
# 1.0         4.776744  142.530233      71.065116      22.293023  100.390698
#
#                BMI  DiabetesPedigreeFunction        Age fl_date  \
# Outcome
# 0.0      30.361654                  0.434882  31.365915     NaN
# 1.0      35.641395                  0.553372  36.860465     NaN
#
#         unique_carrier  ...  fl_num origin  dest dep_time dep_delay  arr_time  \
# Outcome                 ...
# 0.0                NaN  ...     NaN    NaN   NaN      NaN       NaN       NaN
# 1.0                NaN  ...     NaN    NaN   NaN      NaN       NaN       NaN
#
#          arr_delay  cancelled  arr  dep
# Outcome
# 0.0            NaN        NaN  NaN  NaN
# 1.0            NaN        NaN  NaN  NaN
#
# [2 rows x 22 columns]

# %%
combined_df.groupby("Outcome").median()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
combined_df.shape
# Out:
# (21431, 23)

# %%
combined_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'fl_date',
#        'unique_carrier', 'airline_id', 'tail_num', 'fl_num', 'origin', 'dest',
#        'dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'cancelled', 'arr',
#        'dep'],
#       dtype='object')

# %%
combined_df.dtypes
# Out:
# Pregnancies                 float64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                     float64
# fl_date                      object
# unique_carrier               object
# airline_id                  float64
# tail_num                     object
# fl_num                      float64
# origin                       object
# dest                         object
# dep_time                    float64
# dep_delay                   float64
# arr_time                    float64
# arr_delay                   float64
# cancelled                   float64
# arr                          object
# dep                          object
# dtype: object

# %%
combined_df.tail()
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 21426          NaN      NaN            NaN            NaN      NaN  NaN
# 21427          NaN      NaN            NaN            NaN      NaN  NaN
# 21428          NaN      NaN            NaN            NaN      NaN  NaN
# 21429          NaN      NaN            NaN            NaN      NaN  NaN
# 21430          NaN      NaN            NaN            NaN      NaN  NaN
#
#        DiabetesPedigreeFunction  Age  Outcome              fl_date  ...  \
# 21426                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21427                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21428                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21429                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
# 21430                       NaN  NaN      NaN  2014-01-31 00:00:00  ...
#
#        fl_num  origin dest  dep_time dep_delay arr_time  arr_delay  cancelled  \
# ...

# %%
combined_df.isnull()
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            False    False          False          False    False  False
# 1            False    False          False          False    False  False
# 2            False    False          False          False    False  False
# 3            False    False          False          False    False  False
# 4            False    False          False          False    False  False
# ...            ...      ...            ...            ...      ...    ...
# 21426         True     True           True           True     True   True
# 21427         True     True           True           True     True   True
# 21428         True     True           True           True     True   True
# 21429         True     True           True           True     True   True
# 21430         True     True           True           True     True   True
#
#        DiabetesPedigreeFunction    Age  Outcome  fl_date  ...  fl_num  origin  \
# ...

# %%
# Question2 diabetes

# %%
df = pd.read_csv("/content/diabetes_model.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.scatter(x="Glucose", y="Outcome")
# Out:
# <Axes: xlabel='Glucose', ylabel='Outcome'>

# %%
df['Age'].corr(df["Pregnancies"])
# Out:
# 0.5527439411474889

# %%
df2.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.box()
# Out:
# <Axes: >
